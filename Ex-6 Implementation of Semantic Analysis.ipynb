# %%
#importing packages
! pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
#reading content from file
f = open("D:\CLG\Sem 6\AAI\EXPs\samplefile.txt", "r")
sentences = f.readlines()
f.close()
verbs = [[] for _ in sentences]
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)

  # Tokenize the sentence into words
  words = word_tokenize(sentence)

  # Identify the parts of speech for each word
  pos_tags = nltk.pos_tag(words)

  # Print the parts of speech
  for word,tag in pos_tags:
    print(word,"->",tag)

    # Save verbs
    if tag.startswith('VB'):
      verbs[i].append(word)
  i+=1
  print("\n\n")
# Identify synonyms and antonyms for each word
print("Synonyms and Antonymns for verbs in each sentence:\n")
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)
  pos_tags = nltk.pos_tag(verbs[i])
  for word,tag in pos_tags:
    print(word,"->",tag)
    synonyms = []
    antonyms = []
    for syn in wordnet.synsets(word):
      for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
          for antonym in lemma.antonyms():
            antonyms.append(antonym.name())

    # Print the synonyms and antonyms
    print("Synonyms:",set(synonyms))
    print("Antonyms:", set(antonyms) if antonyms else "None")
    print()
  print("\n\n")
  i+=1
# Out:
# Requirement already satisfied: nltk in c:\users\venka\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\venka\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\venka\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\venka\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\venka\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\venka\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Sentence 1 : The curious dog chased the red ball through the park.
#
# The -> DT
# curious -> JJ
# dog -> NN
# chased -> VBD
# the -> DT
# red -> JJ
# ball -> NN
# through -> IN
# the -> DT
# park -> NN
# . -> .
#
#
#
# Sentence 2 : Sarah enjoys baking delicious chocolate chip cookies on weekends.
#
# Sarah -> NNP
# enjoys -> VBZ
# baking -> VBG
# delicious -> JJ
# chocolate -> NN
# chip -> NN
# cookies -> NNS
# on -> IN
# weekends -> NNS
# . -> .
#
#
#
# Sentence 3 : Artificial intelligence is rapidly transforming many industries.
#
# Artificial -> JJ
# intelligence -> NN
# is -> VBZ
# rapidly -> RB
# transforming -> VBG
# many -> JJ
# industries -> NNS
# . -> .
#
#
#
# Sentence 4 : Despite the rain, the children played happily in puddles.
#
# Despite -> IN
# the -> DT
# rain -> NN
# , -> ,
# the -> DT
# children -> NNS
# played -> VBD
# happily -> RB
# in -> IN
# puddles -> NNS
# . -> .
#
#
#
# Sentence 5 : This new book explores the history of ancient civilizations.
#
# This -> DT
# new -> JJ
# book -> NN
# explores -> VBZ
# the -> DT
# history -> NN
# of -> IN
# ancient -> JJ
# civilizations -> NNS
# . -> .
#
#
#
# Sentence 6 : The concert was a huge success, with thousands of fans in attendance.
#
# The -> DT
# concert -> NN
# was -> VBD
# a -> DT
# huge -> JJ
# success -> NN
# , -> ,
# with -> IN
# thousands -> NNS
# of -> IN
# fans -> NNS
# in -> IN
# attendance -> NN
# . -> .
#
#
#
# Sentence 7 : John decided to learn a new language this year.
#
# John -> NNP
# decided -> VBD
# to -> TO
# learn -> VB
# a -> DT
# new -> JJ
# language -> NN
# this -> DT
# year -> NN
# . -> .
#
#
#
# Sentence 8 : Medical research is constantly striving to find cures for diseases.
#
# Medical -> JJ
# research -> NN
# is -> VBZ
# constantly -> RB
# striving -> VBG
# to -> TO
# find -> VB
# cures -> NNS
# for -> IN
# diseases -> NNS
# . -> .
#
#
#
# Sentence 9 : The aroma of freshly brewed coffee filled the air.
#
# The -> DT
# aroma -> NN
# of -> IN
# freshly -> JJ
# brewed -> VBN
# coffee -> NN
# filled -> VBD
# the -> DT
# air -> NN
# . -> .
#
#
#
# Sentence 10 : Recycling plastic bottles helps to conserve natural resources.
#
# Recycling -> VBG
# plastic -> NN
# bottles -> NNS
# helps -> VBZ
# to -> TO
# conserve -> VB
# natural -> JJ
# resources -> NNS
# . -> .
#
#
#
# Sentence 11 : The majestic mountains stood tall against the clear blue sky.
#
# The -> DT
# majestic -> JJ
# mountains -> NNS
# stood -> VBD
# tall -> JJ
# against -> IN
# the -> DT
# clear -> JJ
# blue -> NN
# sky -> NN
# . -> .
#
#
#
# Sentence 12 : The library is a treasure trove of knowledge waiting to be explored.
#
# The -> DT
# library -> NN
# is -> VBZ
# a -> DT
# treasure -> NN
# trove -> NN
# of -> IN
# knowledge -> NN
# waiting -> VBG
# to -> TO
# be -> VB
# explored -> VBN
# . -> .
#
#
#
# Sentence 13 : Taking a walk in nature is a great way to relax and de-stress.
#
# Taking -> VBG
# a -> DT
# walk -> NN
# in -> IN
# nature -> NN
# is -> VBZ
# a -> DT
# great -> JJ
# way -> NN
# to -> TO
# relax -> VB
# and -> CC
# de-stress -> NN
# . -> .
#
#
#
# Sentence 14 : Many people enjoy traveling to new and exciting destinations.
#
# Many -> JJ
# people -> NNS
# enjoy -> VBP
# traveling -> VBG
# to -> TO
# new -> JJ
# and -> CC
# exciting -> JJ
# destinations -> NNS
# . -> .
#
#
#
# Sentence 15 : Technology has made communication much faster and easier.
#
# Technology -> NN
# has -> VBZ
# made -> VBN
# communication -> NN
# much -> JJ
# faster -> JJR
# and -> CC
# easier -> JJR
# . -> .
#
#
#
# Sentence 16 : Learning to play a musical instrument can be a rewarding experience.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Learning -> VBG
# to -> TO
# play -> VB
# a -> DT
# musical -> JJ
# instrument -> NN
# can -> MD
# be -> VB
# a -> DT
# rewarding -> JJ
# experience -> NN
# . -> .
#
#
#
# Sentence 17 : Protecting endangered species is crucial for maintaining biodiversity.
#
# Protecting -> VBG
# endangered -> VBN
# species -> NNS
# is -> VBZ
# crucial -> JJ
# for -> IN
# maintaining -> VBG
# biodiversity -> NN
# . -> .
#
#
#
# Sentence 18 : The internet has revolutionized the way we access information.
#
# The -> DT
# internet -> NN
# has -> VBZ
# revolutionized -> VBN
# the -> DT
# way -> NN
# we -> PRP
# access -> NN
# information -> NN
# . -> .
#
#
#
# Sentence 19 : Astronomy allows us to study the vast universe beyond our planet.
#
# Astronomy -> NNP
# allows -> VBZ
# us -> PRP
# to -> TO
# study -> VB
# the -> DT
# vast -> JJ
# universe -> JJ
# beyond -> IN
# our -> PRP$
# planet -> NN
# . -> .
#
#
#
# Sentence 20 : Ecotourism promotes sustainable travel practices.
#
# Ecotourism -> NN
# promotes -> VBZ
# sustainable -> JJ
# travel -> NN
# practices -> NNS
# . -> .
#
#
#
# Sentence 21 : A healthy diet is essential for maintaining good physical health.
#
# A -> DT
# healthy -> JJ
# diet -> NN
# is -> VBZ
# essential -> JJ
# for -> IN
# maintaining -> VBG
# good -> JJ
# physical -> JJ
# health -> NN
# . -> .
#
#
#
# Sentence 22 : Building strong relationships with others is important for emotional well-being.
#
# Building -> NN
# strong -> JJ
# relationships -> NNS
# with -> IN
# others -> NNS
# is -> VBZ
# important -> JJ
# for -> IN
# emotional -> JJ
# well-being -> NN
# . -> .
#
#
#
# Sentence 23 : Climate change is a major challenge facing our planet today.
#
# Climate -> NNP
# change -> NN
# is -> VBZ
# a -> DT
# major -> JJ
# challenge -> NN
# facing -> VBG
# our -> PRP$
# planet -> NN
# today -> NN
# . -> .
#
#
#
# Sentence 24 : Renewable energy sources like solar and wind power are becoming increasingly popular.
#
# Renewable -> JJ
# energy -> NN
# sources -> NNS
# like -> IN
# solar -> JJ
# and -> CC
# wind -> JJ
# power -> NN
# are -> VBP
# becoming -> VBG
# increasingly -> RB
# popular -> JJ
# . -> .
#
#
#
# Sentence 25 : Space exploration allows us to learn more about the origins of our universe.
#
# Space -> NNP
# exploration -> NN
# allows -> VBZ
# us -> PRP
# to -> TO
# learn -> VB
# more -> JJR
# about -> IN
# the -> DT
# origins -> NNS
# of -> IN
# our -> PRP$
# universe -> NN
# . -> .
#
#
#
# Sentence 26 : Volunteering your time to help others can be a rewarding experience.
#
# Volunteering -> VBG
# your -> PRP$
# time -> NN
# to -> TO
# help -> VB
# others -> NNS
# can -> MD
# be -> VB
# a -> DT
# rewarding -> JJ
# experience -> NN
# . -> .
#
#
#
# Sentence 27 : Critical thinking skills are essential for success in today's world.
#
# Critical -> JJ
# thinking -> NN
# skills -> NNS
# are -> VBP
# essential -> JJ
# for -> IN
# success -> NN
# in -> IN
# today -> NN
# 's -> POS
# world -> NN
# . -> .
#
#
#
# Sentence 28 : The power of imagination allows us to create and innovate.
#
# The -> DT
# power -> NN
# of -> IN
# imagination -> NN
# allows -> VBZ
# us -> PRP
# to -> TO
# create -> VB
# and -> CC
# innovate -> VB
# . -> .
#
#
#
# Sentence 29 : Developing a strong work ethic is important for achieving your goals.
#
# Developing -> VBG
# a -> DT
# strong -> JJ
# work -> NN
# ethic -> NN
# is -> VBZ
# important -> JJ
# for -> IN
# achieving -> VBG
# your -> PRP$
# goals -> NNS
# . -> .
#
#
#
# Sentence 30 : Education is the key to unlocking your full potential.
# Education -> NN
# is -> VBZ
# the -> DT
# key -> NN
# to -> TO
# unlocking -> VB
# your -> PRP$
# full -> JJ
# potential -> NN
# . -> .
#
#
#
# Synonyms and Antonymns for verbs in each sentence:
#
# Sentence 1 : The curious dog chased the red ball through the park.
#
# chased -> VBN
# Synonyms: {'dog', 'chase', 'furrow', 'chamfer', 'track', 'tail', 'trail', 'go_after', 'chase_after', 'chased', 'tag', 'pursued', 'give_chase'}
# Antonyms: None
#
#
#
#
# Sentence 2 : Sarah enjoys baking delicious chocolate chip cookies on weekends.
#
# enjoys -> NNS
# Synonyms: {'love', 'delight', 'relish', 'revel', 'bask', 'savor', 'enjoy', 'savour'}
# Antonyms: {'suffer'}
#
# baking -> VBG
# Synonyms: {'baking_hot', 'bake', 'broil', 'baking'}
# Antonyms: None
#
#
#
#
# Sentence 3 : Artificial intelligence is rapidly transforming many industries.
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# transforming -> VBG
# Synonyms: {'metamorphose', 'translate', 'transubstantiate', 'transform', 'transmute'}
# Antonyms: None
#
#
#
#
# Sentence 4 : Despite the rain, the children played happily in puddles.
#
# played -> NNS
# Synonyms: {'play', 'playact', 'fiddle', 'meet', 'wager', 'dally', 'represent', 'spiel', 'played', 'take_on', 'act_as', 'wreak', 'roleplay', 'work', 'flirt', 'toy', 'act', 'bring', 'run', 'make_for', 'trifle', 'bet', 'encounter', 'diddle', 'recreate'}
# Antonyms: None
#
#
#
#
# Sentence 5 : This new book explores the history of ancient civilizations.
#
# explores -> NNS
# Synonyms: {'explore', 'research', 'search'}
# Antonyms: None
#
#
#
#
# Sentence 6 : The concert was a huge success, with thousands of fans in attendance.
#
# was -> VBD
# Synonyms: {'WA', 'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'Washington', 'follow', 'Evergreen_State', 'exist', 'make_up', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 7 : John decided to learn a new language this year.
#
# decided -> VBD
# Synonyms: {'decided', 'adjudicate', 'settle', "make_up_one's_mind", 'determine', 'distinct', 'resolve', 'decide'}
# Antonyms: None
#
# learn -> NN
# Synonyms: {'get_word', 'see', 'find_out', 'memorise', 'check', 'learn', 'study', 'acquire', 'watch', 'read', 'instruct', 'teach', 'pick_up', 'larn', 'get_wind', 'get_a_line', 'hear', 'discover', 'memorize', 'ascertain', 'determine', 'take', 'con'}
# Antonyms: None
#
#
#
#
# Sentence 8 : Medical research is constantly striving to find cures for diseases.
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# striving -> VBG
# Synonyms: {'nisus', 'pains', 'strive', 'strain', 'reach', 'endeavor', 'endeavour', 'striving'}
# Antonyms: None
#
# find -> VB
# Synonyms: {'happen', 'chance', 'see', 'find_out', 'get_hold', 'rule', 'come_up', 'obtain', 'incur', 'receive', 'find', 'notice', 'find_oneself', 'bump', 'line_up', 'feel', 'witness', 'observe', 'get', 'discover', 'regain', 'discovery', 'uncovering', 'ascertain', 'recover', 'retrieve', 'breakthrough', 'encounter', 'detect', 'determine'}
# Antonyms: {'lose'}
#
#
#
#
# Sentence 9 : The aroma of freshly brewed coffee filled the air.
#
# brewed -> VBN
# Synonyms: {'brew'}
# Antonyms: None
#
# filled -> VBD
# Synonyms: {'occupy', 'fulfill', 'fulfil', 'sate', 'fill', 'make_full', 'fill_up', 'filled', 'satisfy', 'satiate', 'take', 'meet', 'replete'}
# Antonyms: {'empty', 'unfilled'}
#
#
#
#
# Sentence 10 : Recycling plastic bottles helps to conserve natural resources.
#
# Recycling -> VBG
# Synonyms: {'recycle', 'recycling', 'reprocess', 'reuse'}
# Antonyms: None
#
# helps -> VBZ
# Synonyms: {'helper', 'avail', 'help', 'serve', 'aid', 'supporter', 'service', 'assistance', 'assist', 'assistant', 'facilitate', 'help_oneself'}
# Antonyms: None
#
# conserve -> VB
# Synonyms: {'conserves', 'preserve', 'maintain', 'husband', 'economize', 'conserve', 'economise', 'keep_up', 'preserves'}
# Antonyms: {'waste'}
#
#
#
#
# Sentence 11 : The majestic mountains stood tall against the clear blue sky.
#
# stood -> NN
# Synonyms: {'support', 'resist', 'brook', 'abide', 'stand_up', 'stand', 'digest', 'endure', 'put_up', 'stomach', 'place_upright', 'tolerate', 'remain_firm', 'fend', 'stick_out', 'bear', 'suffer'}
# Antonyms: {'lie', 'yield', 'sit'}
#
#
#
#
# Sentence 12 : The library is a treasure trove of knowledge waiting to be explored.
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# waiting -> VBG
# Synonyms: {'await', 'ready_and_waiting', 'hold_back', 'look', 'waiting', 'hold_off', 'expect', 'wait', 'waitress'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'be', 'constitute', 'represent', 'atomic_number_4', 'comprise', 'personify', 'cost', 'beryllium', 'follow', 'make_up', 'exist', 'embody', 'live', 'glucinium', 'equal', 'Be'}
# Antonyms: {'differ'}
#
# explored -> VBN
# Synonyms: {'explore', 'research', 'search'}
# Antonyms: None
#
#
#
#
# Sentence 13 : Taking a walk in nature is a great way to relax and de-stress.
#
# Taking -> VBG
# Synonyms: {'use_up', 'remove', 'guide', 'involve', 'shoot', 'pack', 'consume', 'rent', 'assume', 'charter', 'fetching', 'lease', 'contain', 'learn', 'engage', 'withdraw', 'study', 'carry', 'strike', 'take_aim', 'call_for', 'pickings', 'acquire', 'adopt', 'choose', 'demand', 'admit', 'subscribe_to', 'look_at', 'winning', 'pick_out', 'read', 'select', 'direct', 'take_on', 'drive', 'occupy', 'take_away', 'film', 'fill', 'claim', 'get', 'take_up', 'consider', 'hold', 'conduct', 'contract', 'taking', 'have', 'ask', 'ingest', 'bring', 'convey', 'subscribe', 'accept', 'make', 'postulate', 'get_hold_of', 'train', 'necessitate', 'submit', 'take_in', 'take', 'deal', 'exact', 'aim', 'lead', 'need', 'require', 'hire'}
# Antonyms: {'abstain', 'obviate', 'refuse', 'disclaim', 'give'}
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# relax -> NN
# Synonyms: {'loose', 'unbend', 'unstrain', 'unwind', 'slow_down', 'loosen', 'make_relaxed', 'relax', 'decompress', 'slacken', 'slack', 'unlax', 'loosen_up', 'slack_up'}
# Antonyms: {'strain', 'tense', 'stiffen'}
#
#
#
#
# Sentence 14 : Many people enjoy traveling to new and exciting destinations.
#
# enjoy -> NN
# Synonyms: {'love', 'delight', 'relish', 'revel', 'bask', 'savor', 'enjoy', 'savour'}
# Antonyms: {'suffer'}
#
# traveling -> VBG
# Synonyms: {'go', 'travel', 'traveling', 'travelling', 'journey', 'trip', 'move', 'jaunt', 'move_around', 'locomote'}
# Antonyms: {'stay_in_place'}
#
#
#
#
# Sentence 15 : Technology has made communication much faster and easier.
#
# has -> VBZ
# Synonyms: {'hour_angle', 'induce', 'throw', 'consume', 'feature', 'experience', 'cause', 'deliver', 'receive', 'let', 'HA', 'bear', 'give', 'birth', 'own', 'have_got', 'get', 'hold', 'have', 'sustain', 'make', 'accept', 'stimulate', 'take_in', 'give_birth', 'take', 'ingest', 'suffer', 'possess'}
# Antonyms: {'lack', 'refuse', 'abstain'}
#
# made -> VBN
# Synonyms: {'constitute', 'induce', 'pull_in', 'shit', 'crap', 'prepare', 'throw', 'hit', 'ca-ca', 'arrive_at', 'stool', 'create', 'seduce', 'establish', 'score', 'bring_in', 'earn', 'do', 'lay_down', 'relieve_oneself', 'clear', 'wee-wee', 'made', 'take_a_leak', 'pass_water', 'cause', 'take_a_crap', 'wee', 'give', 'defecate', 'fix', 'make_believe', 'gain', 'get_to', 'micturate', 'ready', 'spend_a_penny', 'realise', 'progress_to', 'get', 'make_up', 'reach', 'piddle', 'produce', 'hold', 'urinate', 'have', 'form', 'take_a_shit', 'work', 'make_water', 'draw', 'build', 'cook', 'puddle', 'make', 'piss', 'name', 'stimulate', 'pee-pee', 'pee', 'take_in', 'realize', 'take', 'nominate', 'construct', 'attain', 'pretend'}
# Antonyms: {'unmade', 'break', 'unmake'}
#
#
#
#
# Sentence 16 : Learning to play a musical instrument can be a rewarding experience.
#
# Learning -> VBG
# Synonyms: {'get_word', 'see', 'find_out', 'memorise', 'check', 'learn', 'study', 'acquisition', 'acquire', 'watch', 'eruditeness', 'read', 'instruct', 'teach', 'pick_up', 'larn', 'get_wind', 'get_a_line', 'encyclopaedism', 'learning', 'hear', 'discover', 'memorize', 'erudition', 'scholarship', 'ascertain', 'encyclopedism', 'determine', 'take', 'con', 'learnedness'}
# Antonyms: None
#
# play -> NN
# Synonyms: {'gambol', 'gambling', 'play', 'swordplay', 'drama', "child's_play", 'playact', 'fiddle', 'gaming', 'manoeuvre', 'turn', 'meet', 'wager', 'dally', 'represent', 'maneuver', 'caper', 'free_rein', 'spiel', 'frolic', 'fun', 'take_on', 'shimmer', 'bid', 'act_as', 'wreak', 'roleplay', 'period_of_play', 'dramatic_play', 'flirt', 'work', 'toy', 'act', 'bring', 'run', 'make_for', 'sport', 'trifle', 'playing_period', 'looseness', 'bet', 'encounter', 'diddle', 'romp', 'recreate'}
# Antonyms: {'tightness'}
#
# be -> VB
# Synonyms: {'be', 'constitute', 'represent', 'atomic_number_4', 'comprise', 'personify', 'cost', 'beryllium', 'follow', 'make_up', 'exist', 'embody', 'live', 'glucinium', 'equal', 'Be'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 17 : Protecting endangered species is crucial for maintaining biodiversity.
#
# Protecting -> VBG
# Synonyms: {'protecting', 'protect'}
# Antonyms: None
#
# endangered -> VBN
# Synonyms: {'expose', 'scupper', 'jeopardize', 'imperil', 'threaten', 'queer', 'endanger', 'peril', 'endangered', 'jeopardise', 'menace'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# maintaining -> VBG
# Synonyms: {'preserve', 'maintain', 'uphold', 'exert', 'observe', 'keep', 'conserve', 'hold', 'assert', 'asseverate', 'wield', 'sustain', 'keep_up', 'defend'}
# Antonyms: None
#
#
#
#
# Sentence 18 : The internet has revolutionized the way we access information.
#
# has -> VBZ
# Synonyms: {'hour_angle', 'induce', 'throw', 'consume', 'feature', 'experience', 'cause', 'deliver', 'receive', 'let', 'HA', 'bear', 'give', 'birth', 'own', 'have_got', 'get', 'hold', 'have', 'sustain', 'make', 'accept', 'stimulate', 'take_in', 'give_birth', 'take', 'ingest', 'suffer', 'possess'}
# Antonyms: {'lack', 'refuse', 'abstain'}
#
# revolutionized -> VBN
# Synonyms: {'revolutionize', 'revolutionise', 'inspire', 'overturn'}
# Antonyms: None
#
#
#
#
# Sentence 19 : Astronomy allows us to study the vast universe beyond our planet.
#
# allows -> NNS
# Synonyms: {'earmark', 'take_into_account', 'grant', 'provide', 'give_up', 'reserve', 'allow_for', 'admit', 'tolerate', 'let', 'appropriate', 'permit', 'allow', 'countenance', 'leave', 'set_aside'}
# Antonyms: {'deny', 'forbid', 'prevent', 'disallow'}
#
# study -> NN
# Synonyms: {'examine', 'cogitation', 'written_report', 'meditate', 'field', 'learn', 'study', 'subject_field', 'read', 'analyze', 'subject_area', 'canvas', 'analyse', 'contemplate', 'survey', 'consider', 'discipline', 'work', 'sketch', 'hit_the_books', 'canvass', 'bailiwick', 'field_of_study', 'report', 'subject', 'take'}
# Antonyms: None
#
#
#
#
# Sentence 20 : Ecotourism promotes sustainable travel practices.
#
# promotes -> NNS
# Synonyms: {'push', 'kick_upstairs', 'further', 'promote', 'advertise', 'upgrade', 'raise', 'advance', 'boost', 'elevate', 'advertize', 'encourage'}
# Antonyms: {'demote'}
#
#
#
#
# Sentence 21 : A healthy diet is essential for maintaining good physical health.
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# maintaining -> VBG
# Synonyms: {'preserve', 'maintain', 'uphold', 'exert', 'observe', 'keep', 'conserve', 'hold', 'assert', 'asseverate', 'wield', 'sustain', 'keep_up', 'defend'}
# Antonyms: None
#
#
#
#
# Sentence 22 : Building strong relationships with others is important for emotional well-being.
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 23 : Climate change is a major challenge facing our planet today.
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# facing -> VBG
# Synonyms: {'confront', 'veneer', 'facing', 'cladding', 'front', 'look', 'present', 'face_up', 'lining', 'face'}
# Antonyms: {'back', 'avoid'}
#
#
#
#
# Sentence 24 : Renewable energy sources like solar and wind power are becoming increasingly popular.
#
# are -> VBP
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'are', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal', 'ar'}
# Antonyms: {'differ'}
#
# becoming -> VBG
# Synonyms: {'decent', 'decorous', 'go', 'suit', 'comme_il_faut', 'becoming', 'get', 'become', 'turn', 'comely', 'seemly'}
# Antonyms: None
#
#
#
#
# Sentence 25 : Space exploration allows us to learn more about the origins of our universe.
#
# allows -> NNS
# Synonyms: {'earmark', 'take_into_account', 'grant', 'provide', 'give_up', 'reserve', 'allow_for', 'admit', 'tolerate', 'let', 'appropriate', 'permit', 'allow', 'countenance', 'leave', 'set_aside'}
# Antonyms: {'deny', 'forbid', 'prevent', 'disallow'}
#
# learn -> VBP
# Synonyms: {'get_word', 'see', 'find_out', 'memorise', 'check', 'learn', 'study', 'acquire', 'watch', 'read', 'instruct', 'teach', 'pick_up', 'larn', 'get_wind', 'get_a_line', 'hear', 'discover', 'memorize', 'ascertain', 'determine', 'take', 'con'}
# Antonyms: None
#
#
#
#
# Sentence 26 : Volunteering your time to help others can be a rewarding experience.
#
# Volunteering -> VBG
# Synonyms: {'volunteer', 'offer'}
# Antonyms: None
#
# help -> NN
# Synonyms: {'helper', 'avail', 'help', 'serve', 'aid', 'supporter', 'service', 'assistance', 'assist', 'assistant', 'facilitate', 'help_oneself'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'be', 'constitute', 'represent', 'atomic_number_4', 'comprise', 'personify', 'cost', 'beryllium', 'follow', 'make_up', 'exist', 'embody', 'live', 'glucinium', 'equal', 'Be'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 27 : Critical thinking skills are essential for success in today's world.
#
# are -> VBP
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'are', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal', 'ar'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 28 : The power of imagination allows us to create and innovate.
#
# allows -> NNS
# Synonyms: {'earmark', 'take_into_account', 'grant', 'provide', 'give_up', 'reserve', 'allow_for', 'admit', 'tolerate', 'let', 'appropriate', 'permit', 'allow', 'countenance', 'leave', 'set_aside'}
# Antonyms: {'deny', 'forbid', 'prevent', 'disallow'}
#
# create -> VBP
# Synonyms: {'make', 'produce', 'create'}
# Antonyms: None
#
# innovate -> NN
# Synonyms: {'introduce', 'innovate'}
# Antonyms: None
#
#
#
#
# Sentence 29 : Developing a strong work ethic is important for achieving your goals.
#
# Developing -> VBG
# Synonyms: {'originate', 'prepare', 'rise', 'developing', 'underdeveloped', 'educate', 'acquire', 'grow', 'modernize', 'germinate', 'evolve', 'break', 'formulate', 'explicate', 'uprise', 'get', 'make_grow', 'produce', 'modernise', 'development', 'train', 'recrudesce', 'arise', 'spring_up', 'develop', 'build_up'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# achieving -> VBG
# Synonyms: {'reach', 'accomplish', 'achieve', 'attain'}
# Antonyms: None
#
#
#
#
# Sentence 30 : Education is the key to unlocking your full potential.
# is -> VBZ
# Synonyms: {'be', 'constitute', 'represent', 'comprise', 'personify', 'cost', 'follow', 'make_up', 'exist', 'embody', 'live', 'equal'}
# Antonyms: {'differ'}
#
# unlocking -> VBG
# Synonyms: {'unlock'}
# Antonyms: {'lock'}
